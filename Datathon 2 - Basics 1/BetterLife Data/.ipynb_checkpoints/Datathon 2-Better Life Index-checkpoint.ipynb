# %% [markdown]
# # Basic Imports

# %%
import numpy as np  #load up the libraries and object defs. we need
import pandas as pd
from pandas import DataFrame, Series

# load up my visualization system, and call the object plt
import matplotlib.pyplot as plt

# tell ipython notebook to print visualizations inline
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Load Data

# %%
# A subset of data from the OECD Better Life Index (...and an incomplete one at that)
df = pd.read_excel('BetterLifeIndex.xlsx',skiprows=2) # Drop the non-data rows at the top

# %%
df.head(5) # Get a quick sample
# Out:
#      Country  Employment rate  Long-term unemployment rate  Student skills  \
# 0  Australia               72                         1.32             512
# 1    Austria               71                         1.53             500
# 2    Belgium               62                         4.26             509
# 3     Canada               72                         0.89             522
# 4      Chile               62                         1.67             436
#
#    Years in education  Air pollution  Water quality  Life expectancy  \
# 0                19.2              6             94             82.2
# 1                17.1             15             93             81.2
# 2                18.8             19             83             80.7
# 3                16.3             12             90             81.5
# 4                17.1             18             71             78.8
#
#    Life satisfaction  Feeling safe walking alone at night  Homicide rate
# 0                7.3                                 62.6            0.8
# 1                7.1                                 81.2            0.4
# 2                6.9                                 69.6            1.1
# 3                7.4                                 81.7            1.5
# 4                6.5                                 50.2            3.8

# %%
# We can do math with these
df["Homicide rate"] + df["Feeling safe walking alone at night"]
# Out:
# 0     63.4
# 1     81.6
# 2     70.7
# 3     83.2
# 4     54.0
# 5     71.0
# 6     85.5
# 7     72.0
# 8     87.3
# 9     71.2
# 10    75.1
# 11    64.0
# 12    54.4
# 13    78.4
# 14    77.8
# 15    68.1
# 16    60.1
# 17    70.5
# 18    68.8
# 19    67.7
# 20    70.8
# 21    63.3
# 22    81.3
# 23    65.6
# 24    90.6
# 25    67.1
# 26    70.1
# 27    63.3
# 28    84.3
# 29    82.2
# 30    77.6
# 31    87.9
# 32    62.1
# 33    78.0
# 34    79.1
# dtype: float64

# %%
# And create new columns
df["My Safety Score"] = (df["Homicide rate"] + df["Feeling safe walking alone at night"]) 
df.sample(5)
# Out:
#           Country  Employment rate  Long-term unemployment rate  \
# 18          Korea               65                         0.01
# 34  United States               68                         1.42
# 31    Switzerland               80                         1.71
# 28       Slovenia               64                         5.27
# 3          Canada               72                         0.89
#
#     Student skills  Years in education  Air pollution  Water quality  \
# 18             542                17.5             29             78
# 34             492                17.1             11             84
# 31             518                17.4             17             97
# 28             499                18.3             14             91
# 3              522                16.3             12             90
#
#     Life expectancy  Life satisfaction  Feeling safe walking alone at night  \
# 18             81.8                5.8                                 67.7
# 34             78.8                6.9                                 73.9
# 31             82.9                7.6                                 87.4
# 28             80.4                5.7                                 83.9
# 3              81.5                7.4                                 81.7
#
#     Homicide rate  My Safety Score
# 18            1.1             68.8
# 34            5.2             79.1
# 31            0.5             87.9
# 28            0.4             84.3
# 3             1.5             83.2

# %% [markdown]
# ^ _but is this actually a good composite score?_

# %%
# We might want to consider normalizing these so they're weighted more evenly
hr = df["Homicide rate"] 
df["Homicide rate (normalized)"] = (hr-hr.min())/(hr.max()-hr.min())
df.sample(5)
# Out:
#     Country  Employment rate  Long-term unemployment rate  Student skills  \
# 7   Estonia               70                         3.32             526
# 9    France               64                         4.21             500
# 2   Belgium               62                         4.26             509
# 8   Finland               69                         1.97             529
# 13  Iceland               82                         0.67             484
#
#     Years in education  Air pollution  Water quality  Life expectancy  \
# 7                 17.8              9             84             77.3
# 9                 16.4             14             84             82.3
# 2                 18.8             19             83             80.7
# 8                 19.7              7             94             81.1
# 13                19.6              7             97             82.1
#
#     Life satisfaction  Feeling safe walking alone at night  Homicide rate  \
# 7                 5.6                                 67.2            4.8
# 9                 6.4                                 70.6            0.6
# 2                 6.9                                 69.6            1.1
# 8                 7.4                                 85.8            1.5
# 13                7.5                                 78.1            0.3
#
#     My Safety Score  Homicide rate (normalized)
# 7              72.0                    0.198276
# 9              71.2                    0.017241
# 2              70.7                    0.038793
# 8              87.3                    0.056034
# 13             78.4                    0.004310

# %%
# A different way to perform computations on a whole column
df[['Homicide rate']].apply(lambda x: (x - x.mean()) / (x.max() - x.min())) # (here normalized distance from the mean)
# Out:
#     Homicide rate
# 0       -0.050739
# 1       -0.067980
# 2       -0.037808
# 3       -0.020567
# 4        0.078571
# 5       -0.046429
# 6       -0.072291
# 7        0.121675
# 8       -0.020567
# 9       -0.059360
# 10      -0.063670
# 11      -0.020567
# 12      -0.033498
# 13      -0.072291
# 14      -0.050739
# 15      -0.007635
# 16      -0.050739
# 17      -0.072291
# 18      -0.037808
# 19       0.177709
# 20      -0.076601
# 21       0.923399
# 22      -0.050739
# 23      -0.033498
# 24      -0.042118
# 25      -0.042118
# 26      -0.046429
# 27      -0.033498
# 28      -0.067980
# 29      -0.059360
# 30      -0.050739
# 31      -0.063670
# 32      -0.011946
# 33      -0.076601
# 34       0.138916

# %%
# In case you want to index by country (remember that this creates a copy of the DataFrame)
new_df = df.set_index('Country')

# %%
new_df["Canada":"Canada"]
# Out:
#          Employment rate  Long-term unemployment rate  Student skills  \
# Country
# Canada                72                         0.89             522
#
#          Years in education  Air pollution  Water quality  Life expectancy  \
# Country
# Canada                 16.3             12             90             81.5
#
#          Life satisfaction  Feeling safe walking alone at night  \
# Country
# Canada                 7.4                                 81.7
#
#          Homicide rate  My Safety Score  Homicide rate (normalized)
# Country
# Canada             1.5             83.2                    0.056034

# %% [markdown]
# # Question 1
# What country is the safest?
#
# *Remember, you should be able to clearly **present** the result to an audience (and have them understand how you got it.)*

# %%
fswh = new_df["Feeling safe walking alone at night"] 
new_df["FSWH (normalized)"] = (fswh-fswh.min())/(fswh.max()-fswh.min())
new_df.sample(5)
# Out:
#              Employment rate  Long-term unemployment rate  Student skills  \
# Country
# Germany                   74                         2.21             515
# Switzerland               80                         1.71             518
# Netherlands               73                         2.98             519
# Japan                     73                         1.36             540
# Estonia                   70                         3.32             526
#
#              Years in education  Air pollution  Water quality  \
# Country
# Germany                    18.1             15             94
# Switzerland                17.4             17             97
# Netherlands                17.9             17             94
# Japan                      16.0             16             87
# Estonia                    17.8              9             84
#
#              Life expectancy  Life satisfaction  \
# Country
# Germany                 80.9                7.0
# Switzerland             82.9                7.6
# Netherlands             81.4                7.3
# Japan                   83.4                5.9
# Estonia                 77.3                5.6
#
#              Feeling safe walking alone at night  Homicide rate  \
# Country
# Germany                                     74.6            0.5
# Switzerland                                 87.4            0.5
# Netherlands                                 80.5            0.8
# Japan                                       70.2            0.3
# Estonia                                     67.2            4.8
#
#              My Safety Score  Homicide rate (normalized)  FSWH (normalized)
# Country
# Germany                 75.1                    0.012931           0.698189
# Switzerland             87.9                    0.012931           0.955734
# Netherlands             81.3                    0.025862           0.816901
# Japan                   70.5                    0.004310           0.609658
# Estonia                 72.0                    0.198276           0.549296

# %%
air_poll = new_df["Air pollution"] 
new_df["Air poll (normalized)"] = (air_poll-air_poll.min())/(air_poll.max()-air_poll.min())
new_df.sample(5)
# Out:
#                  Employment rate  Long-term unemployment rate  Student skills  \
# Country
# Mexico                        60                         0.06             417
# Italy                         57                         7.79             490
# Estonia                       70                         3.32             526
# Slovak Republic               61                         8.80             472
# Hungary                       62                         3.78             487
#
#                  Years in education  Air pollution  Water quality  \
# Country
# Mexico                         14.4             12             68
# Italy                          16.8             18             70
# Estonia                        17.8              9             84
# Slovak Republic                16.2             16             81
# Hungary                        17.2             16             76
#
#                  Life expectancy  Life satisfaction  \
# Country
# Mexico                      74.6                6.2
# Italy                       82.8                5.8
# Estonia                     77.3                5.6
# Slovak Republic             76.5                6.2
# Hungary                     75.7                5.3
#
#                  Feeling safe walking alone at night  Homicide rate  \
# Country
# Mexico                                          39.9           23.4
# Italy                                           59.3            0.8
# Estonia                                         67.2            4.8
# Slovak Republic                                 62.1            1.2
# Hungary                                         53.2            1.2
#
#                  My Safety Score  Homicide rate (normalized)  \
# Country
# Mexico                      63.3                    1.000000
# Italy                       60.1                    0.025862
# Estonia                     72.0                    0.198276
# Slovak Republic             63.3                    0.043103
# Hungary                     54.4                    0.043103
#
#                  FSWH (normalized)  Air poll (normalized)
# Country
# Mexico                    0.000000               0.260870
# Italy                     0.390342               0.521739
# Estonia                   0.549296               0.130435
# Slovak Republic           0.446680               0.434783
# Hungary                   0.267606               0.434783

# %%
water_qual = new_df["Water quality"] 
new_df["Water qual (normalized)"] = (water_qual-water_qual.min())/(water_qual.max()-water_qual.min())
new_df.sample(5)
# Out:
#                 Employment rate  Long-term unemployment rate  Student skills  \
# Country
# Israel                       68                         0.63             474
# Poland                       62                         3.26             521
# Norway                       75                         0.41             496
# Czech Republic               69                         2.72             500
# Greece                       49                        19.47             466
#
#                 Years in education  Air pollution  Water quality  \
# Country
# Israel                        15.9             26             65
# Poland                        17.9             17             80
# Norway                        18.0              6             97
# Czech Republic                17.4             17             88
# Greece                        18.5             15             69
#
#                 Life expectancy  Life satisfaction  \
# Country
# Israel                     82.1                7.1
# Poland                     77.1                6.0
# Norway                     81.8                7.6
# Czech Republic             78.3                6.6
# Greece                     81.4                5.6
#
#                 Feeling safe walking alone at night  Homicide rate  \
# Country
# Israel                                         66.3            1.8
# Poland                                         66.1            1.0
# Norway                                         89.6            1.0
# Czech Republic                                 70.1            0.9
# Greece                                         62.5            1.5
#
#                 My Safety Score  Homicide rate (normalized)  \
# Country
# Israel                     68.1                    0.068966
# Poland                     67.1                    0.034483
# Norway                     90.6                    0.034483
# Czech Republic             71.0                    0.030172
# Greece                     64.0                    0.056034
#
#                 FSWH (normalized)  Air poll (normalized)  \
# Country
# Israel                   0.531187               0.869565
# Poland                   0.527163               0.478261
# Norway                   1.000000               0.000000
# Czech Republic           0.607646               0.478261
# Greece                   0.454728               0.391304
#
#                 Water qual (normalized)
# Country
# Israel                         0.058824
# Poland                         0.500000
# Norway                         1.000000
# Czech Republic                 0.735294
# Greece                         0.176471

# %%
hrn = new_df["Homicide rate (normalized)"]
fswh_n = new_df["FSWH (normalized)"]
air_poll_n = new_df["Air poll (normalized)"]
water_qual_n = new_df["Water qual (normalized)"]
new_df["Safety Score"] = -(hrn*5) + (fswh_n*1) - (air_poll_n*2) + (water_qual_n*2)

# %%
new_df = new_df.sort_values('Safety Score', ascending=False)
new_df.head(20)
# Out:
#                 Employment rate  Long-term unemployment rate  Student skills  \
# Country
# Norway                       75                         0.41             496
# Iceland                      82                         0.67             484
# Sweden                       75                         1.33             482
# Finland                      69                         1.97             529
# Denmark                      73                         1.66             498
# Australia                    72                         1.32             512
# Switzerland                  80                         1.71             518
# Slovenia                     64                         5.27             499
# Austria                      71                         1.53             500
# United Kingdom               73                         2.22             502
# New Zealand                  74                         0.78             509
# Germany                      74                         2.21             515
# Canada                       72                         0.89             522
# Portugal                     63                         8.28             488
# Ireland                      61                         6.98             516
# Netherlands                  73                         2.98             519
# Japan                        73                         1.36             540
# Luxembourg                   67                         1.60             490
# France                       64                         4.21             500
# Czech Republic               69                         2.72             500
#
#                 Years in education  Air pollution  Water quality  \
# Country
# Norway                        18.0              6             97
# Iceland                       19.6              7             97
# Sweden                        19.1              7             95
# Finland                       19.7              7             94
# Denmark                       19.6             11             95
# Australia                     19.2              6             94
# Switzerland                   17.4             17             97
# Slovenia                      18.3             14             91
# Austria                       17.1             15             93
# United Kingdom                16.7             11             87
# New Zealand                   18.0              9             92
# Germany                       18.1             15             94
# Canada                        16.3             12             90
# Portugal                      17.4             10             89
# Ireland                       17.8              8             82
# Netherlands                   17.9             17             94
# Japan                         16.0             16             87
# Luxembourg                    15.1             15             85
# France                        16.4             14             84
# Czech Republic                17.4             17             88
#
#                 Life expectancy  Life satisfaction  \
# Country
# Norway                     81.8                7.6
# Iceland                    82.1                7.5
# Sweden                     82.0                7.3
# Finland                    81.1                7.4
# Denmark                    80.4                7.5
# Australia                  82.2                7.3
# Switzerland                82.9                7.6
# Slovenia                   80.4                5.7
# Austria                    81.2                7.1
# United Kingdom             81.1                6.5
# New Zealand                81.4                7.4
# Germany                    80.9                7.0
# Canada                     81.5                7.4
# Portugal                   80.8                5.1
# Ireland                    81.1                6.8
# Netherlands                81.4                7.3
# Japan                      83.4                5.9
# Luxembourg                 81.9                6.7
# France                     82.3                6.4
# Czech Republic             78.3                6.6
#
#                 Feeling safe walking alone at night  Homicide rate  \
# Country
# Norway                                         89.6            1.0
# Iceland                                        78.1            0.3
# Sweden                                         76.8            0.8
# Finland                                        85.8            1.5
# Denmark                                        85.2            0.3
# Australia                                      62.6            0.8
# Switzerland                                    87.4            0.5
# Slovenia                                       83.9            0.4
# Austria                                        81.2            0.4
# United Kingdom                                 77.8            0.2
# New Zealand                                    64.4            1.2
# Germany                                        74.6            0.5
# Canada                                         81.7            1.5
# Portugal                                       69.2            0.9
# Ireland                                        77.0            0.8
# Netherlands                                    80.5            0.8
# Japan                                          70.2            0.3
# Luxembourg                                     70.6            0.2
# France                                         70.6            0.6
# Czech Republic                                 70.1            0.9
#
#                 My Safety Score  Homicide rate (normalized)  \
# Country
# Norway                     90.6                    0.034483
# Iceland                    78.4                    0.004310
# Sweden                     77.6                    0.025862
# Finland                    87.3                    0.056034
# Denmark                    85.5                    0.004310
# Australia                  63.4                    0.025862
# Switzerland                87.9                    0.012931
# Slovenia                   84.3                    0.008621
# Austria                    81.6                    0.008621
# United Kingdom             78.0                    0.000000
# New Zealand                65.6                    0.043103
# Germany                    75.1                    0.012931
# Canada                     83.2                    0.056034
# Portugal                   70.1                    0.030172
# Ireland                    77.8                    0.025862
# Netherlands                81.3                    0.025862
# Japan                      70.5                    0.004310
# Luxembourg                 70.8                    0.000000
# France                     71.2                    0.017241
# Czech Republic             71.0                    0.030172
#
#                 FSWH (normalized)  Air poll (normalized)  \
# Country
# Norway                   1.000000               0.000000
# Iceland                  0.768612               0.043478
# Sweden                   0.742455               0.043478
# Finland                  0.923541               0.043478
# Denmark                  0.911469               0.217391
# Australia                0.456740               0.000000
# Switzerland              0.955734               0.478261
# Slovenia                 0.885312               0.347826
# Austria                  0.830986               0.391304
# United Kingdom           0.762575               0.217391
# New Zealand              0.492958               0.130435
# Germany                  0.698189               0.391304
# Canada                   0.841046               0.260870
# Portugal                 0.589537               0.173913
# Ireland                  0.746479               0.086957
# Netherlands              0.816901               0.478261
# Japan                    0.609658               0.434783
# Luxembourg               0.617706               0.391304
# France                   0.617706               0.347826
# Czech Republic           0.607646               0.478261
#
#                 Water qual (normalized)  Safety Score
# Country
# Norway                         1.000000      2.827586
# Iceland                        1.000000      2.660103
# Sweden                         0.941176      2.408541
# Finland                        0.911765      2.379942
# Denmark                        0.941176      2.337487
# Australia                      0.911765      2.150960
# Switzerland                    1.000000      1.934557
# Slovenia                       0.823529      1.793615
# Austria                        0.882353      1.769980
# United Kingdom                 0.705882      1.739558
# New Zealand                    0.852941      1.722453
# Germany                        0.911765      1.674455
# Canada                         0.794118      1.627370
# Portugal                       0.764706      1.620261
# Ireland                        0.558824      1.560903
# Netherlands                    0.911765      1.554599
# Japan                          0.705882      1.130306
# Luxembourg                     0.647059      1.129215
# France                         0.617647      1.071141
# Czech Republic                 0.735294      0.970850

# %% [markdown]
# The safest country is Norway.

# %% [markdown]
# # Question 2
# On average what is the **life satisfaction** of the five countries with the **most years in education**?

# %%
q2 = df.sort_values('Years in education', ascending=False).head(5)

# %%
q2["Life satisfaction"].mean()
# Out:
# 7.4

# %% [markdown]
# The average life satisfaction of the five countries with the most years of education is 7.4.

# %% [markdown]
# # Question 3
# What is the distribution of life expectancy across OECD countries?
# Are there other indicators with similar distributions? Do you think they are related?

# %%
df["Life expectancy"].hist(bins=10)

# %%
_ = df[["Employment rate","Long-term unemployment rate","Student skills","Years in education","Air pollution","Water quality","Life expectancy","Life satisfaction","Feeling safe walking alone at night","Homicide rate"]].hist(bins=10, figsize=(15,10))

# %% [markdown]
# ## It appears as though Student Skills, Water Quality, and Years in Education all have somewhat similar distributions.

# %%
_ = df.plot(kind="scatter", x="Life expectancy", y="Student skills", figsize=(20,10))
_ = df.plot(kind="scatter", x="Life expectancy", y="Water quality", figsize=(20,10))
_ = df.plot(kind="scatter", x="Life expectancy", y="Years in education", figsize=(20,10))

# %% [markdown]
# ## Upon further inspection, each of the scatter plots seems to imply a vaguely linear correlation; with Student Skills being the most visible linear.

# %% [markdown]
# # Question 4
# Do Student Skills really correlate with Life Expectancy?

# %%
import seaborn as sns
sns.set(font_scale=1.75)
sns.set_style("white")

q4 = pd.read_excel('BetterLifeIndex2.xlsx',skiprows=2)

q4 = q4.sort_values('Life expectancy', ascending=False)

q4a = q4.head(10)
q4b = q4.tail(10)

a_countries = q4a.Country.unique()
b_countries = q4b.Country.unique()

# %%
top_countries = q4[q4['Country'].isin(a_countries)]
bot_countries = q4[q4['Country'].isin(b_countries)]

# %%
g = sns.lmplot(x='Life expectancy', y='Student skills', hue='Country', data=top_countries, size=9, ci=None)

g.set_axis_labels('Life Expectancy', 'Student Skills')

axes = g.axes
axes[0,0].set_ylim(450,550)
# Out:
# (450, 550)

# %%
g = sns.lmplot(x='Life expectancy', y='Student skills', hue='Country', data=bot_countries, size=9, ci=None)

g.set_axis_labels('Life Expectancy', 'Student Skills')

axes = g.axes
axes[0,0].set_ylim(450,550)
# Out:
# (450, 550)
